# %% [markdown]
# ### Laoding Liblaries and data

# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array
import warnings
warnings.filterwarnings("ignore")

# %%
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, mode='rt', encoding='utf-8')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# %%
filename = 'deu.txt'
doc = load_doc(filename)
# doc

# %%
# split a loaded document into sentences
def to_pairs(doc):
    lines = doc.strip().split('\n')
    pairs = [line.split('\t') for line in lines]
    return pairs

# %%
# clean a list of lines
def clean_pairs(lines):
    cleaned = list()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    re_print = re.compile('[^%s]' % re.escape(string.printable))
    for pair in lines:
        clean_pair = list()
        for line in pair:
            # normalize unicode characters
            line = normalize('NFD', line).encode('ascii', 'ignore')
            line = line.decode('UTF-8')
            # tokenize on white space
            line = line.split()
            # convert to lowercase
            line = [word.lower() for word in line]
            # remove punctuation from each token
            line = [re_punc.sub('', w) for w in line]
            # remove non-printable chars form each token
            line = [re_print.sub('', w) for w in line]
            # remove tokens with numbers in them
            line = [word for word in line if word.isalpha()]
            # store as string
            clean_pair.append(' '.join(line))
        cleaned.append(clean_pair)
    return array(cleaned)

# %%
# save a list of clean sentences to file
def save_clean_data(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)

# %%
# load dataset
filename = 'deu.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-german.pkl')
# spot check
for i in range(100):
    print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-german.pkl
# [go] => [geh]
# [hi] => [hallo]
# [hi] => [gru gott]
# [run] => [lauf]
# [run] => [lauf]
# [wow] => [potzdonner]
# [wow] => [donnerwetter]
# [duck] => [kopf runter]
# [fire] => [feuer]
# [help] => [hilfe]
# [help] => [zu hulf]
# [hide] => [versteck dich]
# [hide] => [versteckt euch]
# [stay] => [bleib]
# [stop] => [stopp]
# [stop] => [anhalten]
# [wait] => [warte]
# [wait] => [warte]
# [begin] => [fang an]
# [do it] => [mache es]
# [do it] => [tue es]
# [go on] => [mach weiter]
# [hello] => [hallo]
# [hello] => [sers]
# [hello] => [hallo]
# [hurry] => [beeil dich]
# [hurry] => [schnell]
# [i hid] => [ich versteckte mich]
# [i hid] => [ich habe mich versteckt]
# [i ran] => [ich rannte]
# [i see] => [ich verstehe]
# [i see] => [aha]
# [i try] => [ich versuche es]
# [i try] => [ich probiere es]
# [i won] => [ich hab gewonnen]
# [i won] => [ich habe gewonnen]
# [i won] => [ich habe gewonnen]
# [oh no] => [oh nein]
# [relax] => [entspann dich]
# [shoot] => [feuer]
# [shoot] => [schie]
# [smile] => [lacheln]
# [sorry] => [entschuldigung]
# [ask me] => [frag mich]
# [ask me] => [fragt mich]
# [ask me] => [fragen sie mich]
# [attack] => [angriff]
# [attack] => [attacke]
# [buy it] => [kaufs]
# [cheers] => [zum wohl]
# [eat it] => [iss es]
# [eat up] => [iss fertig]
# [eat up] => [iss auf]
# [eat up] => [iss auf]
# [exhale] => [ausatmen]
# [freeze] => [keine bewegung]
# [freeze] => [stehenbleiben]
# [go now] => [geh jetzt]
# [got it] => [verstanden]
# [got it] => [ich habs]
# [got it] => [aha]
# [got it] => [kapiert]
# [got it] => [verstanden]
# [got it] => [einverstanden]
# [he ran] => [er rannte]
# [he ran] => [er lief]
# [hop in] => [mach mit]
# [hop in] => [spring rein]
# [hug me] => [druck mich]
# [hug me] => [nimm mich in den arm]
# [hug me] => [umarme mich]
# [i care] => [mir ist es wichtig]
# [i fell] => [ich fiel]
# [i fell] => [ich fiel hin]
# [i fell] => [ich sturzte]
# [i fell] => [ich bin hingefallen]
# [i fell] => [ich bin gesturzt]
# [i fled] => [ich fluchtete]
# [i fled] => [ich bin gefluchtet]
# [i know] => [ich wei]
# [i lied] => [ich habe gelogen]
# [i lost] => [ich habe verloren]
# [i paid] => [ich habe bezahlt]
# [i paid] => [ich zahlte]
# [i pass] => [ich passe]
# [i sang] => [ich sang]
# [i spit] => [ich spuckte]
# [i spit] => [ich habe gespuckt]
# [i swim] => [ich schwimme]
# [i wept] => [ich weinte]
# [i wept] => [ich habe geweint]
# [im] => [ich bin jahre alt]
# [im] => [ich bin]
# [im ok] => [mir gehts gut]
# [im ok] => [es geht mir gut]
# [im up] => [ich bin wach]
# [im up] => [ich bin auf]
# [inhale] => [einatmen]
# [listen] => [hort zu]
# [no way] => [unmoglich]

# %% [markdown]
# ### Split Text

# %%
from pickle import load
from pickle import dump
from numpy.random import shuffle

# %%
# load a clean dataset
def load_clean_sentences(filename):
    return load(open(filename, 'rb'))

# %%
# save a list of clean sentences to file
def save_clean_data(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)

# %%
# load dataset
raw_dataset = load_clean_sentences('english-german.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[9000:]
# save
save_clean_data(dataset, 'english-german-both.pkl')
save_clean_data(train, 'english-german-train.pkl')
save_clean_data(test, 'english-german-test.pkl')
# Out:
# Saved: english-german-both.pkl
# Saved: english-german-train.pkl
# Saved: english-german-test.pkl

# %%
raw_dataset.shape
# Out:
# (277891, 3)

# %%
dataset
# Out:
# array([['tom can walk', 'tom kann laufen',
#         'ccby france attribution tatoebaorg ck yorwba'],
#        ['i like art', 'ich mag kunst',
#         'ccby france attribution tatoebaorg ck yorwba'],
#        ['well ask tom', 'wir werden tom fragen',
#         'ccby france attribution tatoebaorg ck felixjp'],
#        ...,
#        ['watch my back', 'gib mir ruckendeckung',
#         'ccby france attribution tatoebaorg spamster pfirsichbaeumchen'],
#        ['im a doctor', 'ich bin arzt',
#         'ccby france attribution tatoebaorg ck muiriel'],
#        ['its a fad', 'das ist eine vorubergehende laune',
#         'ccby france attribution tatoebaorg spamster pfirsichbaeumchen']],
#       dtype='<U527')

# %% [markdown]
# ### Train Neural Translation Model

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
# from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# %%
# load a clean dataset
def load_clean_sentences(filename):
    return load(open(filename, 'rb'))
# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')

# %%
print(train.shape)
print(test.shape)
# Out:
# (9000, 3)
# (1000, 3)

# %%
train
# Out:
# array([['tom can walk', 'tom kann laufen',
#         'ccby france attribution tatoebaorg ck yorwba'],
#        ['i like art', 'ich mag kunst',
#         'ccby france attribution tatoebaorg ck yorwba'],
#        ['well ask tom', 'wir werden tom fragen',
#         'ccby france attribution tatoebaorg ck felixjp'],
#        ...,
#        ['he came', 'er kam',
#         'ccby france attribution tatoebaorg piksea espi'],
#        ['im a colonel', 'ich bin oberst',
#         'ccby france attribution tatoebaorg ck pfirsichbaeumchen'],
#        ['i never worry', 'ich mache mir nie sorgen',
#         'ccby france attribution tatoebaorg ck mayabe']], dtype='<U527')

# %%
test
# Out:
# array([['tom is hated', 'tom wird gehasst',
#         'ccby france attribution tatoebaorg ck wolfgangth'],
#        ['see you again', 'auf wiedersehen',
#         'ccby france attribution tatoebaorg ck muiriel'],
#        ['everybody lies', 'alle lugen',
#         'ccby france attribution tatoebaorg goracykabanos muiriel'],
#        ...,
#        ['watch my back', 'gib mir ruckendeckung',
#         'ccby france attribution tatoebaorg spamster pfirsichbaeumchen'],
#        ['im a doctor', 'ich bin arzt',
#         'ccby france attribution tatoebaorg ck muiriel'],
#        ['its a fad', 'das ist eine vorubergehende laune',
#         'ccby france attribution tatoebaorg spamster pfirsichbaeumchen']],
#       dtype='<U527')

# %%
# fit a tokenizer
def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %%
# max sentence length
def max_length(lines):
    return max(len(line.split()) for line in lines)

# %%
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('German Vocabulary Size: %d' % ger_vocab_size)
print('German Max Length: %d' % (ger_length))
# Out:
# English Vocabulary Size: 2172
# English Max Length: 5
# German Vocabulary Size: 3578
# German Max Length: 8

# %%
eng_tokenizer

# %%
eng_tokenizer.word_index
# Out:
# {'i': 1,
#  'tom': 2,
#  'it': 3,
#  'you': 4,
#  'is': 5,
#  'a': 6,
#  'im': 7,
#  'was': 8,
#  'me': 9,
#  'he': 10,
#  'we': 11,
#  'go': 12,
#  'its': 13,
#  'do': 14,
#  'can': 15,
#  'dont': 16,
#  'are': 17,
#  'ill': 18,
#  'that': 19,
#  'this': 20,
#  'get': 21,
#  'were': 22,
#  'to': 23,
#  'come': 24,
#  'have': 25,
#  'youre': 26,
#  'be': 27,
#  'up': 28,
#  'the': 29,
#  'like': 30,
#  'my': 31,
#  'in': 32,
#  'who': 33,
#  'toms': 34,
#  'love': 35,
#  'here': 36,
#  'they': 37,
#  'did': 38,
#  'on': 39,
#  'am': 40,
#  'keep': 41,
#  'she': 42,
#  'take': 43,
#  'us': 44,
#  'need': 45,
#  'stop': 46,
#  'not': 47,
#  'him': 48,
#  'thats': 49,
#  'want': 50,
#  'now': 51,
#  'how': 52,
#  'no': 53,
#  'well': 54,
#  'let': 55,
#  'home': 56,
#  'hes': 57,
#  'try': 58,
#  'away': 59,
#  'know': 60,
#  'lost': 61,
#  'saw': 62,
#  'help': 63,
#  'got': 64,
#  'out': 65,
#  'see': 66,
#  'one': 67,
#  'has': 68,
#  'will': 69,
#  'theyre': 70,
#  'eat': 71,
#  'down': 72,
#  'too': 73,
#  'look': 74,
#  'hate': 75,
#  'there': 76,
#  'cant': 77,
#  'lets': 78,
#  'wait': 79,
#  'just': 80,
#  'what': 81,
#  'so': 82,
#  'stay': 83,
#  'busy': 84,
#  'back': 85,
#  'ok': 86,
#  'give': 87,
#  'may': 88,
#  'for': 89,
#  'them': 90,
#  'work': 91,
#  'please': 92,
#  'hurt': 93,
#  'feel': 94,
#  'good': 95,
#  'sick': 96,
#  'ask': 97,
#  'at': 98,
#  'came': 99,
#  'again': 100,
#  'her': 101,
#  'right': 102,
#  'made': 103,
#  'all': 104,
#  'had': 105,
#  'walk': 106,
#  'went': 107,
#  'must': 108,
#  'found': 109,
#  'happy': 110,
#  'sing': 111,
#  'car': 112,
#  'hard': 113,
#  'whos': 114,
#  'start': 115,
#  'ready': 116,
#  'an': 117,
#  'mine': 118,
#  'with': 119,
#  'say': 120,
#  'swim': 121,
#  'your': 122,
#  'check': 123,
#  'cold': 124,
#  'alone': 125,
#  'read': 126,
#  'wont': 127,
#  'win': 128,
#  'hot': 129,
#  'said': 130,
#  'late': 131,
#  'drunk': 132,
#  'off': 133,
#  'ate': 134,
#  'over': 135,
#  'didnt': 136,
#  'hold': 137,
#  'call': 138,
#  'very': 139,
#  'sad': 140,
#  'quiet': 141,
#  'talk': 142,
#  'wasnt': 143,
#  'miss': 144,
#  'wrong': 145,
#  'won': 146,
#  'leave': 147,
#  'hurry': 148,
#  'lying': 149,
#  'show': 150,
#  'fun': 151,
#  'more': 152,
#  'new': 153,
#  'bad': 154,
#  'mad': 155,
#  'use': 156,
#  'fast': 157,
#  'die': 158,
#  'watch': 159,
#  'knew': 160,
#  'ive': 161,
#  'angry': 162,
#  'upset': 163,
#  'isnt': 164,
#  'lot': 165,
#  'time': 166,
#  'nobody': 167,
#  'why': 168,
#  'beat': 169,
#  'drink': 170,
#  'dog': 171,
#  'fine': 172,
#  'open': 173,
#  'cry': 174,
#  'nice': 175,
#  'bed': 176,
#  'bored': 177,
#  'left': 178,
#  'by': 179,
#  'cool': 180,
#  'never': 181,
#  'mary': 182,
#  'cook': 183,
#  'turn': 184,
#  'stand': 185,
#  'quit': 186,
#  'ran': 187,
#  'whats': 188,
#  'called': 189,
#  'money': 190,
#  'drive': 191,
#  'felt': 192,
#  'trust': 193,
#  'tea': 194,
#  'think': 195,
#  'run': 196,
#  'tell': 197,
#  'does': 198,
#  'crazy': 199,
#  'hurts': 200,
#  'way': 201,
#  'lie': 202,
#  'fish': 203,
#  'knows': 204,
#  'broke': 205,
#  'bit': 206,
#  'of': 207,
#  'move': 208,
#  'dying': 209,
#  'fix': 210,
#  'buy': 211,
#  'put': 212,
#  'easy': 213,
#  'job': 214,
#  'old': 215,
#  'hit': 216,
#  'life': 217,
#  'joking': 218,
#  'book': 219,
#  'free': 220,
#  'pay': 221,
#  'stupid': 222,
#  'yourself': 223,
#  'loved': 224,
#  'tomll': 225,
#  'tired': 226,
#  'some': 227,
#  'safe': 228,
#  'cut': 229,
#  'shes': 230,
#  'catch': 231,
#  'young': 232,
#  'met': 233,
#  'door': 234,
#  'fell': 235,
#  'tried': 236,
#  'bring': 237,
#  'big': 238,
#  'early': 239,
#  'sit': 240,
#  'french': 241,
#  'rich': 242,
#  'shot': 243,
#  'hug': 244,
#  'live': 245,
#  'rest': 246,
#  'where': 247,
#  'make': 248,
#  'fat': 249,
#  'sorry': 250,
#  'find': 251,
#  'bus': 252,
#  'food': 253,
#  'shy': 254,
#  'these': 255,
#  'great': 256,
#  'naive': 257,
#  'close': 258,
#  'and': 259,
#  'kill': 260,
#  'told': 261,
#  'yours': 262,
#  'helped': 263,
#  'looks': 264,
#  'awake': 265,
#  'write': 266,
#  'fired': 267,
#  'mean': 268,
#  'hope': 269,
#  'cried': 270,
#  'nothing': 271,
#  'still': 272,
#  'speak': 273,
#  'forget': 274,
#  'break': 275,
#  'reading': 276,
#  'man': 277,
#  'true': 278,
#  'cheated': 279,
#  'brave': 280,
#  'inside': 281,
#  'ours': 282,
#  'id': 283,
#  'itll': 284,
#  'boy': 285,
#  'coffee': 286,
#  'begin': 287,
#  'coming': 288,
#  'careful': 289,
#  'cat': 290,
#  'sure': 291,
#  'wine': 292,
#  'loves': 293,
#  'beer': 294,
#  'weak': 295,
#  'mind': 296,
#  'agree': 297,
#  'dogs': 298,
#  'clean': 299,
#  'kids': 300,
#  'first': 301,
#  'hungry': 302,
#  'enjoy': 303,
#  'running': 304,
#  'looked': 305,
#  'tall': 306,
#  'study': 307,
#  'gone': 308,
#  'singing': 309,
#  'wholl': 310,
#  'lose': 311,
#  'guess': 312,
#  'map': 313,
#  'blind': 314,
#  'weird': 315,
#  'vote': 316,
#  'cute': 317,
#  'sang': 318,
#  'touch': 319,
#  'should': 320,
#  'could': 321,
#  'soon': 322,
#  'alive': 323,
#  'calm': 324,
#  'smiled': 325,
#  'red': 326,
#  'water': 327,
#  'bet': 328,
#  'died': 329,
#  'lucky': 330,
#  'hugged': 331,
#  'step': 332,
#  'dad': 333,
#  'hear': 334,
#  'dead': 335,
#  'ugly': 336,
#  'fighting': 337,
#  'wants': 338,
#  'going': 339,
#  'follow': 340,
#  'wake': 341,
#  'phoned': 342,
#  'joke': 343,
#  'likes': 344,
#  'next': 345,
#  'strong': 346,
#  'school': 347,
#  'care': 348,
#  'half': 349,
#  'applauded': 350,
#  'gave': 351,
#  'fail': 352,
#  'working': 353,
#  'ones': 354,
#  'warm': 355,
#  'survived': 356,
#  'goodbye': 357,
#  'stood': 358,
#  'crying': 359,
#  'changed': 360,
#  'lied': 361,
#  'thanks': 362,
#  'afraid': 363,
#  'rude': 364,
#  'hated': 365,
#  'needs': 366,
#  'paid': 367,
#  'done': 368,
#  'head': 369,
#  'hired': 370,
#  'better': 371,
#  'smart': 372,
#  'seems': 373,
#  'everybody': 374,
#  'fly': 375,
#  'disagreed': 376,
#  'wet': 377,
#  'best': 378,
#  'boston': 379,
#  'answer': 380,
#  'fair': 381,
#  'remember': 382,
#  'hide': 383,
#  'trying': 384,
#  'kind': 385,
#  'bought': 386,
#  'eggs': 387,
#  'walked': 388,
#  'black': 389,
#  'caution': 390,
#  'lonely': 391,
#  'thin': 392,
#  'tv': 393,
#  'play': 394,
#  'youve': 395,
#  'theyll': 396,
#  'low': 397,
#  'sweet': 398,
#  'hand': 399,
#  'quickly': 400,
#  'ahead': 401,
#  'once': 402,
#  'works': 403,
#  'dancing': 404,
#  'teach': 405,
#  'hello': 406,
#  'happened': 407,
#  'tough': 408,
#  'shame': 409,
#  'eating': 410,
#  'worry': 411,
#  'runs': 412,
#  'wife': 413,
#  'liked': 414,
#  'hang': 415,
#  'moved': 416,
#  'laughed': 417,
#  'pick': 418,
#  'talking': 419,
#  'sat': 420,
#  'started': 421,
#  'asleep': 422,
#  'deaf': 423,
#  'smell': 424,
#  'watched': 425,
#  'spy': 426,
#  'woke': 427,
#  'drank': 428,
#  'student': 429,
#  'drop': 430,
#  'his': 431,
#  'silly': 432,
#  'change': 433,
#  'dream': 434,
#  'forward': 435,
#  'heres': 436,
#  'scary': 437,
#  'stopped': 438,
#  'sleep': 439,
#  'cares': 440,
#  'jump': 441,
#  'shoot': 442,
#  'lock': 443,
#  'dizzy': 444,
#  'weve': 445,
#  'slept': 446,
#  'listen': 447,
#  'serious': 448,
#  'panicked': 449,
#  'smile': 450,
#  'writing': 451,
#  'sec': 452,
#  'losing': 453,
#  'worked': 454,
#  'thirsty': 455,
#  'kid': 456,
#  'join': 457,
#  'closely': 458,
#  'famous': 459,
#  'key': 460,
#  'scared': 461,
#  'stayed': 462,
#  'shut': 463,
#  'rice': 464,
#  'liar': 465,
#  'obey': 466,
#  'around': 467,
#  'cruel': 468,
#  'built': 469,
#  'cats': 470,
#  'girls': 471,
#  'smoke': 472,
#  'moment': 473,
#  'fainted': 474,
#  'patient': 475,
#  'promised': 476,
#  'spoke': 477,
#  'moving': 478,
#  'something': 479,
#  'drove': 480,
#  'count': 481,
#  'helps': 482,
#  'hows': 483,
#  'seen': 484,
#  'blame': 485,
#  'eyes': 486,
#  'son': 487,
#  'kiss': 488,
#  'fire': 489,
#  'correct': 490,
#  'sign': 491,
#  'send': 492,
#  'yes': 493,
#  'ignore': 494,
#  'gun': 495,
#  'took': 496,
#  'relaxed': 497,
#  'hi': 498,
#  'nuts': 499,
#  'arent': 500,
#  'sent': 501,
#  'math': 502,
#  'canceled': 503,
#  'hiding': 504,
#  'winning': 505,
#  'excuse': 506,
#  'useless': 507,
#  'bike': 508,
#  'warn': 509,
#  'enough': 510,
#  'fight': 511,
#  'asked': 512,
#  'men': 513,
#  'notes': 514,
#  'poor': 515,
#  'leaving': 516,
#  'sharp': 517,
#  'okay': 518,
#  'yoga': 519,
#  'birds': 520,
#  'milk': 521,
#  'dj': 522,
#  'rain': 523,
#  'god': 524,
#  'adore': 525,
#  'grab': 526,
#  'spit': 527,
#  'dieting': 528,
#  'stoned': 529,
#  'bald': 530,
#  'burned': 531,
#  'breathe': 532,
#  'closer': 533,
#  'downstairs': 534,
#  'relented': 535,
#  'tidy': 536,
#  'curious': 537,
#  'someone': 538,
#  'boil': 539,
#  'kidding': 540,
#  'resigned': 541,
#  'skate': 542,
#  'swam': 543,
#  'single': 544,
#  'learn': 545,
#  'admire': 546,
#  'agreed': 547,
#  'list': 548,
#  'relax': 549,
#  'vain': 550,
#  'seat': 551,
#  'tries': 552,
#  'pity': 553,
#  'studying': 554,
#  'doctor': 555,
#  'slipped': 556,
#  'saved': 557,
#  'obeyed': 558,
#  'last': 559,
#  'slowly': 560,
#  'meat': 561,
#  'laugh': 562,
#  'obese': 563,
#  'failed': 564,
#  'horse': 565,
#  'funny': 566,
#  'wise': 567,
#  'everyone': 568,
#  'arrived': 569,
#  'oh': 570,
#  'smiling': 571,
#  'boring': 572,
#  'replace': 573,
#  'music': 574,
#  'mom': 575,
#  'fixed': 576,
#  'escaped': 577,
#  'paying': 578,
#  'dance': 579,
#  'outside': 580,
#  'tomorrow': 581,
#  'short': 582,
#  'another': 583,
#  'white': 584,
#  'wash': 585,
#  'age': 586,
#  'humming': 587,
#  'manage': 588,
#  'dozed': 589,
#  'fishing': 590,
#  'witty': 591,
#  'ski': 592,
#  'guilty': 593,
#  'thank': 594,
#  'really': 595,
#  'fake': 596,
#  'room': 597,
#  'wanted': 598,
#  'our': 599,
#  'enter': 600,
#  'card': 601,
#  'war': 602,
#  'scream': 603,
#  'full': 604,
#  'kept': 605,
#  'aside': 606,
#  'duty': 607,
#  'fasting': 608,
#  'awful': 609,
#  'expert': 610,
#  'hey': 611,
#  'deeply': 612,
#  'forgive': 613,
#  'truck': 614,
#  'superb': 615,
#  'already': 616,
#  'evil': 617,
#  'chubby': 618,
#  'eaten': 619,
#  'wasted': 620,
#  'only': 621,
#  'often': 622,
#  'walking': 623,
#  'stuck': 624,
#  'strange': 625,
#  'unwell': 626,
#  'shaved': 627,
#  'overslept': 628,
#  'prayed': 629,
#  'youll': 630,
#  'lazy': 631,
#  'lunch': 632,
#  'blue': 633,
#  'save': 634,
#  'kissed': 635,
#  'suit': 636,
#  'polite': 637,
#  'trusted': 638,
#  'cab': 639,
#  'aboard': 640,
#  'listened': 641,
#  'decide': 642,
#  'quick': 643,
#  'braked': 644,
#  'pale': 645,
#  'cheat': 646,
#  'vanished': 647,
#  'upstairs': 648,
#  'about': 649,
#  'dumped': 650,
#  'today': 651,
#  'unfair': 652,
#  'dark': 653,
#  'push': 654,
#  'naked': 655,
#  'talked': 656,
#  'course': 657,
#  'began': 658,
#  'poet': 659,
#  'anyway': 660,
#  'faster': 661,
#  'biased': 662,
#  'married': 663,
#  'nervous': 664,
#  'cake': 665,
#  'harder': 666,
#  'seriously': 667,
#  'driving': 668,
#  'real': 669,
#  'security': 670,
#  'ashamed': 671,
#  'kite': 672,
#  'pen': 673,
#  'legal': 674,
#  'heard': 675,
#  'fear': 676,
#  'feet': 677,
#  'later': 678,
#  'forgot': 679,
#  'friends': 680,
#  'followed': 681,
#  'egg': 682,
#  'squinted': 683,
#  'night': 684,
#  'urgent': 685,
#  'things': 686,
#  'teacher': 687,
#  'snow': 688,
#  'talks': 689,
#  'denied': 690,
#  'small': 691,
#  'staying': 692,
#  'turned': 693,
#  'gate': 694,
#  'boss': 695,
#  'skating': 696,
#  'guy': 697,
#  'creative': 698,
#  'broken': 699,
#  'brief': 700,
#  'which': 701,
#  'pull': 702,
#  'flies': 703,
#  'ufo': 704,
#  'focused': 705,
#  'anything': 706,
#  'simple': 707,
#  'face': 708,
#  'prisoner': 709,
#  'lungs': 710,
#  'catholic': 711,
#  'fall': 712,
#  'quietly': 713,
#  'proof': 714,
#  'blushed': 715,
#  'raise': 716,
#  'comes': 717,
#  'hers': 718,
#  'wept': 719,
#  'always': 720,
#  'missed': 721,
#  'minute': 722,
#  'fit': 723,
#  'anybody': 724,
#  'yet': 725,
#  'gets': 726,
#  'foggy': 727,
#  'ruthless': 728,
#  'popular': 729,
#  'knelt': 730,
#  'confused': 731,
#  'team': 732,
#  'fool': 733,
#  'tipsy': 734,
#  'picky': 735,
#  'freezing': 736,
#  'word': 737,
#  'apologize': 738,
#  'shoving': 739,
#  'seem': 740,
#  'far': 741,
#  'uninsured': 742,
#  'scare': 743,
#  'roll': 744,
#  'dice': 745,
#  'stick': 746,
#  'hesitated': 747,
#  'thatll': 748,
#  'nap': 749,
#  'yelled': 750,
#  'pretty': 751,
#  'shooting': 752,
#  'dressed': 753,
#  'as': 754,
#  'avoids': 755,
#  'sell': 756,
#  'fruit': 757,
#  'perfect': 758,
#  'almost': 759,
#  'believed': 760,
#  'long': 761,
#  'closed': 762,
#  'sleepy': 763,
#  'sue': 764,
#  'hid': 765,
#  'livid': 766,
#  'bread': 767,
#  'accept': 768,
#  'cover': 769,
#  'whining': 770,
#  'add': 771,
#  'dug': 772,
#  'hole': 773,
#  'welcome': 774,
#  'punctual': 775,
#  'apples': 776,
#  'grumbled': 777,
#  'set': 778,
#  'twin': 779,
#  'absent': 780,
#  'fist': 781,
#  'hat': 782,
#  'two': 783,
#  'moaned': 784,
#  'hates': 785,
#  'everything': 786,
#  'thirty': 787,
#  'looking': 788,
#  'rested': 789,
#  'dry': 790,
#  'clever': 791,
#  'cash': 792,
#  'ice': 793,
#  'grown': 794,
#  'thisll': 795,
#  'after': 796,
#  'foot': 797,
#  'kneeled': 798,
#  'prefer': 799,
#  'voted': 800,
#  'unkind': 801,
#  'memorize': 802,
#  'succeeded': 803,
#  'armed': 804,
#  'bath': 805,
#  'yelling': 806,
#  'phone': 807,
#  'walks': 808,
#  'bigot': 809,
#  'own': 810,
#  'humor': 811,
#  'aim': 812,
#  'doesnt': 813,
#  'both': 814,
#  'stunned': 815,
#  'candy': 816,
#  'ears': 817,
#  'diabetic': 818,
#  'hung': 819,
#  'boys': 820,
#  'even': 821,
#  'monday': 822,
#  'plan': 823,
#  'artist': 824,
#  'finish': 825,
#  'waited': 826,
#  'skiing': 827,
#  'wicked': 828,
#  'release': 829,
#  'dreams': 830,
#  'believe': 831,
#  'dreaming': 832,
#  'stink': 833,
#  'caught': 834,
#  'canadian': 835,
#  'skinny': 836,
#  'air': 837,
#  'rushed': 838,
#  'attack': 839,
#  'taller': 840,
#  'crafty': 841,
#  'slow': 842,
#  'taste': 843,
#  'discreet': 844,
#  'threw': 845,
#  'lovely': 846,
#  'divorced': 847,
#  'autumn': 848,
#  'normal': 849,
#  'judge': 850,
#  'coughed': 851,
#  'vomit': 852,
#  'worried': 853,
#  'cheered': 854,
#  'giddy': 855,
#  'swore': 856,
#  'unusual': 857,
#  'wolf': 858,
#  'pizza': 859,
#  'any': 860,
#  'flip': 861,
#  'coin': 862,
#  'thatd': 863,
#  'shocked': 864,
#  'song': 865,
#  'waved': 866,
#  'winter': 867,
#  'might': 868,
#  'positive': 869,
#  'yell': 870,
#  'odd': 871,
#  'amazed': 872,
#  'rifle': 873,
#  'hair': 874,
#  'injured': 875,
#  'deny': 876,
#  'happens': 877,
#  'pray': 878,
#  'envy': 879,
#  'drives': 880,
#  'adored': 881,
#  'fan': 882,
#  'pear': 883,
#  'puzzles': 884,
#  'vomited': 885,
#  'swearing': 886,
#  'worse': 887,
#  'ex': 888,
#  'number': 889,
#  'wonderful': 890,
#  'treat': 891,
#  'confessed': 892,
#  'maid': 893,
#  'seated': 894,
#  'sympathize': 895,
#  'rope': 896,
#  'hurried': 897,
#  'wig': 898,
#  'nearby': 899,
#  'travel': 900,
#  'people': 901,
#  'doubts': 902,
#  'repeat': 903,
#  'wrote': 904,
#  'whistled': 905,
#  'healthy': 906,
#  'suits': 907,
#  'hero': 908,
#  'noon': 909,
#  'anyone': 910,
#  'secret': 911,
#  'bat': 912,
#  'exercised': 913,
#  'record': 914,
#  'game': 915,
#  'pass': 916,
#  'thorough': 917,
#  'myself': 918,
#  'action': 919,
#  'faint': 920,
#  'examine': 921,
#  'pushy': 922,
#  'cranky': 923,
#  'idiot': 924,
#  'yawned': 925,
#  'sober': 926,
#  'clapping': 927,
#  'leg': 928,
#  'rush': 929,
#  'those': 930,
#  'approve': 931,
#  'vigilant': 932,
#  'hailed': 933,
#  'loaded': 934,
#  'bowl': 935,
#  'retired': 936,
#  'specific': 937,
#  'objective': 938,
#  'books': 939,
#  'beard': 940,
#  'split': 941,
#  'board': 942,
#  'steal': 943,
#  'abroad': 944,
#  'engaged': 945,
#  'comfort': 946,
#  'loud': 947,
#  'lawyer': 948,
#  'visit': 949,
#  'bless': 950,
#  'insisted': 951,
#  'lay': 952,
#  'became': 953,
#  'contact': 954,
#  'lawyers': 955,
#  'baffled': 956,
#  'soup': 957,
#  'smells': 958,
#  'owe': 959,
#  'cd': 960,
#  'flowers': 961,
#  'seize': 962,
#  'end': 963,
#  'bedtime': 964,
#  'thought': 965,
#  'east': 966,
#  'survive': 967,
#  'showered': 968,
#  'plans': 969,
#  'jam': 970,
#  'grimaced': 971,
#  'honest': 972,
#  'empty': 973,
#  'winked': 974,
#  'many': 975,
#  'froze': 976,
#  'tight': 977,
#  'frank': 978,
#  'second': 979,
#  'curse': 980,
#  'climbing': 981,
#  'gold': 982,
#  'dinners': 983,
#  'salesman': 984,
#  'ride': 985,
#  'addicted': 986,
#  'led': 987,
#  'paused': 988,
#  'town': 989,
#  'youd': 990,
#  'saint': 991,
#  'raining': 992,
#  'giggled': 993,
#  'spring': 994,
#  'exhausted': 995,
#  'higher': 996,
#  'sports': 997,
#  'grouch': 998,
#  'support': 999,
#  'cops': 1000,
#  ...}

# %%
ger_tokenizer.word_index
# Out:
# {'ich': 1,
#  'tom': 2,
#  'ist': 3,
#  'sie': 4,
#  'es': 5,
#  'das': 6,
#  'bin': 7,
#  'wir': 8,
#  'nicht': 9,
#  'habe': 10,
#  'er': 11,
#  'du': 12,
#  'hat': 13,
#  'mich': 14,
#  'zu': 15,
#  'ein': 16,
#  'war': 17,
#  'mir': 18,
#  'sind': 19,
#  'dich': 20,
#  'auf': 21,
#  'uns': 22,
#  'wer': 23,
#  'werde': 24,
#  'kann': 25,
#  'die': 26,
#  'eine': 27,
#  'an': 28,
#  'sich': 29,
#  'ihr': 30,
#  'haben': 31,
#  'bist': 32,
#  'gehen': 33,
#  'hier': 34,
#  'einen': 35,
#  'mal': 36,
#  'wird': 37,
#  'was': 38,
#  'wie': 39,
#  'mag': 40,
#  'ihn': 41,
#  'in': 42,
#  'liebe': 43,
#  'jetzt': 44,
#  'gut': 45,
#  'mach': 46,
#  'euch': 47,
#  'aus': 48,
#  'dir': 49,
#  'lass': 50,
#  'komm': 51,
#  'mit': 52,
#  'geht': 53,
#  'den': 54,
#  'geh': 55,
#  'konnen': 56,
#  'nach': 57,
#  'da': 58,
#  'hause': 59,
#  'wurde': 60,
#  'mein': 61,
#  'will': 62,
#  'werden': 63,
#  'der': 64,
#  'seid': 65,
#  'kommen': 66,
#  'so': 67,
#  'sei': 68,
#  'hast': 69,
#  'brauche': 70,
#  'weiter': 71,
#  'bitte': 72,
#  'fur': 73,
#  'schon': 74,
#  'hatte': 75,
#  'gesehen': 76,
#  'hasse': 77,
#  'weg': 78,
#  'noch': 79,
#  'meine': 80,
#  'machen': 81,
#  'gib': 82,
#  'tun': 83,
#  'kommt': 84,
#  'krank': 85,
#  'essen': 86,
#  'sein': 87,
#  'muss': 88,
#  'macht': 89,
#  'nimm': 90,
#  'beschaftigt': 91,
#  'hor': 92,
#  'gerade': 93,
#  'sehr': 94,
#  'einfach': 95,
#  'bleiben': 96,
#  'gehe': 97,
#  'kannst': 98,
#  'darf': 99,
#  'schnell': 100,
#  'alle': 101,
#  'ab': 102,
#  'helfen': 103,
#  'niemand': 104,
#  'sterben': 105,
#  'recht': 106,
#  'versuchen': 107,
#  'gemacht': 108,
#  'doch': 109,
#  'leben': 110,
#  'gefunden': 111,
#  'bleib': 112,
#  'im': 113,
#  'auto': 114,
#  'tut': 115,
#  'sah': 116,
#  'weh': 117,
#  'mehr': 118,
#  'verloren': 119,
#  'lasst': 120,
#  'zuruck': 121,
#  'ging': 122,
#  'kein': 123,
#  'dem': 124,
#  'nichts': 125,
#  'zeit': 126,
#  'sehen': 127,
#  'ruhig': 128,
#  'wei': 129,
#  'allein': 130,
#  'wieder': 131,
#  'viel': 132,
#  'gehort': 133,
#  'am': 134,
#  'hin': 135,
#  'fuhle': 136,
#  'und': 137,
#  'warten': 138,
#  'hei': 139,
#  'gro': 140,
#  'kam': 141,
#  'gewonnen': 142,
#  'ihm': 143,
#  'lassen': 144,
#  'rein': 145,
#  'glucklich': 146,
#  'fu': 147,
#  'etwas': 148,
#  'gerne': 149,
#  'herein': 150,
#  'ihnen': 151,
#  'mochte': 152,
#  'verruckt': 153,
#  'gegangen': 154,
#  'fahren': 155,
#  'brauchen': 156,
#  'schau': 157,
#  'kalt': 158,
#  'gegessen': 159,
#  'sicher': 160,
#  'thomas': 161,
#  'alt': 162,
#  'spat': 163,
#  'auch': 164,
#  'traurig': 165,
#  'ordnung': 166,
#  'hund': 167,
#  'ja': 168,
#  'vor': 169,
#  'konnt': 170,
#  'seien': 171,
#  'singen': 172,
#  'tee': 173,
#  'dort': 174,
#  'gern': 175,
#  'her': 176,
#  'los': 177,
#  'schlecht': 178,
#  'spa': 179,
#  'komme': 180,
#  'nur': 181,
#  'schwimmen': 182,
#  'habt': 183,
#  'geld': 184,
#  'konnte': 185,
#  'arbeiten': 186,
#  'zieh': 187,
#  'wutend': 188,
#  'nehmen': 189,
#  'gewinnen': 190,
#  'betrunken': 191,
#  'nie': 192,
#  'kennen': 193,
#  'hort': 194,
#  'warte': 195,
#  'keine': 196,
#  'fertig': 197,
#  'mude': 198,
#  'mache': 199,
#  'dran': 200,
#  'fragen': 201,
#  'lesen': 202,
#  'arbeit': 203,
#  'esse': 204,
#  'sehe': 205,
#  'waren': 206,
#  'frei': 207,
#  'angst': 208,
#  'sagte': 209,
#  'gehts': 210,
#  'setz': 211,
#  'stehen': 212,
#  'nett': 213,
#  'liebt': 214,
#  'sag': 215,
#  'von': 216,
#  'getan': 217,
#  'maria': 218,
#  'buch': 219,
#  'wach': 220,
#  'behalten': 221,
#  'wo': 222,
#  'tu': 223,
#  'vorbei': 224,
#  'iss': 225,
#  'versucht': 226,
#  'gesagt': 227,
#  'eins': 228,
#  'bei': 229,
#  'jung': 230,
#  'fang': 231,
#  'probier': 232,
#  'verletzt': 233,
#  'still': 234,
#  'laufen': 235,
#  'mann': 236,
#  'gekommen': 237,
#  'okay': 238,
#  'weinen': 239,
#  'kurz': 240,
#  'raus': 241,
#  'sieht': 242,
#  'halte': 243,
#  'vorsichtig': 244,
#  'neu': 245,
#  'wissen': 246,
#  'weit': 247,
#  'horen': 248,
#  'schlafen': 249,
#  'reich': 250,
#  'braucht': 251,
#  'leid': 252,
#  'lieben': 253,
#  'bus': 254,
#  'wohl': 255,
#  'um': 256,
#  'leise': 257,
#  'meinen': 258,
#  'bett': 259,
#  'dabei': 260,
#  'ganz': 261,
#  'einmal': 262,
#  'fuhlte': 263,
#  'alles': 264,
#  'tur': 265,
#  'bereit': 266,
#  'aufhoren': 267,
#  'hol': 268,
#  'rot': 269,
#  'geschafft': 270,
#  'bring': 271,
#  'bier': 272,
#  'wollen': 273,
#  'fangen': 274,
#  'franzosisch': 275,
#  'langweilig': 276,
#  'angerufen': 277,
#  'nein': 278,
#  'hallo': 279,
#  'schwach': 280,
#  'ernst': 281,
#  'einverstanden': 282,
#  'schule': 283,
#  'kochen': 284,
#  'kinder': 285,
#  'warum': 286,
#  'kaffee': 287,
#  'fruh': 288,
#  'frag': 289,
#  'katze': 290,
#  'runter': 291,
#  'wein': 292,
#  'verlieren': 293,
#  'schuchtern': 294,
#  'reden': 295,
#  'zur': 296,
#  'hunde': 297,
#  'karte': 298,
#  'zuhause': 299,
#  'kaputt': 300,
#  'gefallen': 301,
#  'zeig': 302,
#  'lugen': 303,
#  'diese': 304,
#  'ausruhen': 305,
#  'hoffe': 306,
#  'su': 307,
#  'gelogen': 308,
#  'verargert': 309,
#  'habs': 310,
#  'dick': 311,
#  'fisch': 312,
#  'mussen': 313,
#  'kenne': 314,
#  'besturzt': 315,
#  'kennt': 316,
#  'gestorben': 317,
#  'gebissen': 318,
#  'bleibt': 319,
#  'vielleicht': 320,
#  'wusste': 321,
#  'bezahlen': 322,
#  'neues': 323,
#  'getroffen': 324,
#  'zum': 325,
#  'komisch': 326,
#  'anfangen': 327,
#  'bose': 328,
#  'sprich': 329,
#  'gab': 330,
#  'wirst': 331,
#  'wasser': 332,
#  'meins': 333,
#  'wette': 334,
#  'dies': 335,
#  'witze': 336,
#  'gluck': 337,
#  'siehst': 338,
#  'vater': 339,
#  'bekommen': 340,
#  'ins': 341,
#  'nehme': 342,
#  'als': 343,
#  'sofort': 344,
#  'trinken': 345,
#  'schlie': 346,
#  'drauen': 347,
#  'bord': 348,
#  'danke': 349,
#  'panik': 350,
#  'stark': 351,
#  'fort': 352,
#  'vermisse': 353,
#  'arm': 354,
#  'funktioniert': 355,
#  'sieh': 356,
#  'leg': 357,
#  'geholfen': 358,
#  'warm': 359,
#  'lief': 360,
#  'hierher': 361,
#  'toms': 362,
#  'weinte': 363,
#  'scher': 364,
#  'sauber': 365,
#  'geweint': 366,
#  'dumm': 367,
#  'leine': 368,
#  'schieen': 369,
#  'hilft': 370,
#  'wirklich': 371,
#  'damit': 372,
#  'hab': 373,
#  'ruf': 374,
#  'tot': 375,
#  'gesungen': 376,
#  'gibt': 377,
#  'rannte': 378,
#  'nehmt': 379,
#  'klar': 380,
#  'verirrt': 381,
#  'bisschen': 382,
#  'selbst': 383,
#  'gefallt': 384,
#  'tanzen': 385,
#  'geschlagen': 386,
#  'ubergeben': 387,
#  'witz': 388,
#  'hart': 389,
#  'cool': 390,
#  'boston': 391,
#  'kampfen': 392,
#  'mutig': 393,
#  'warst': 394,
#  'seltsam': 395,
#  'vogel': 396,
#  'hunger': 397,
#  'gekauft': 398,
#  'junge': 399,
#  'versuchs': 400,
#  'geben': 401,
#  'schuld': 402,
#  'deine': 403,
#  'gemein': 404,
#  'eier': 405,
#  'hilfe': 406,
#  'nahe': 407,
#  'bald': 408,
#  'schwarz': 409,
#  'trink': 410,
#  'wagen': 411,
#  'dunn': 412,
#  'uhr': 413,
#  'spazieren': 414,
#  'verstehe': 415,
#  'scheint': 416,
#  'sage': 417,
#  'keiner': 418,
#  'weise': 419,
#  'bringen': 420,
#  'schade': 421,
#  'bezahlt': 422,
#  'blind': 423,
#  'legen': 424,
#  'besser': 425,
#  'vergessen': 426,
#  'klug': 427,
#  'alter': 428,
#  'stimmt': 429,
#  'ski': 430,
#  'fahre': 431,
#  'arbeite': 432,
#  'schreiben': 433,
#  'unrecht': 434,
#  'sies': 435,
#  'frau': 436,
#  'blau': 437,
#  'fangt': 438,
#  'lugt': 439,
#  'kind': 440,
#  'schauen': 441,
#  'fehlt': 442,
#  'schlussel': 443,
#  'fahrt': 444,
#  'oben': 445,
#  'kaufen': 446,
#  'tief': 447,
#  'wahr': 448,
#  'lachelte': 449,
#  'esst': 450,
#  'dass': 451,
#  'gelangweilt': 452,
#  'geliebt': 453,
#  'fallen': 454,
#  'trinke': 455,
#  'halt': 456,
#  'einsam': 457,
#  'entlassen': 458,
#  'steht': 459,
#  'sagen': 460,
#  'ohnmachtig': 461,
#  'halten': 462,
#  'lese': 463,
#  'unhoflich': 464,
#  'vertraue': 465,
#  'worden': 466,
#  'fest': 467,
#  'sprechen': 468,
#  'langsam': 469,
#  'wartet': 470,
#  'fett': 471,
#  'dazu': 472,
#  'liebte': 473,
#  'liegt': 474,
#  'groartig': 475,
#  'dreiig': 476,
#  'lacheln': 477,
#  'geschickt': 478,
#  'beeilen': 479,
#  'lies': 480,
#  'gebe': 481,
#  'anderer': 482,
#  'rauchen': 483,
#  'klein': 484,
#  'bescheid': 485,
#  'bestes': 486,
#  'pleite': 487,
#  'beeil': 488,
#  'lauft': 489,
#  'schneller': 490,
#  'luge': 491,
#  'bewegen': 492,
#  'erinnere': 493,
#  'reinkommen': 494,
#  'musst': 495,
#  'probieren': 496,
#  'beruhmt': 497,
#  'schreien': 498,
#  'sing': 499,
#  'gibts': 500,
#  'blod': 501,
#  'fass': 502,
#  'gott': 503,
#  'schmerzen': 504,
#  'singe': 505,
#  'beginnen': 506,
#  'rennen': 507,
#  'diat': 508,
#  'reis': 509,
#  'lugner': 510,
#  'lie': 511,
#  'vom': 512,
#  'stand': 513,
#  'immer': 514,
#  'naiv': 515,
#  'kniete': 516,
#  'katzen': 517,
#  'madchen': 518,
#  'hatten': 519,
#  'schwer': 520,
#  'drangeln': 521,
#  'dafur': 522,
#  'versprochen': 523,
#  'fuhr': 524,
#  'na': 525,
#  'suchen': 526,
#  'fernsehen': 527,
#  'willst': 528,
#  'ware': 529,
#  'arzt': 530,
#  'musste': 531,
#  'acht': 532,
#  'vertraut': 533,
#  'taxi': 534,
#  'versteckt': 535,
#  'sohn': 536,
#  'a': 537,
#  'gerufen': 538,
#  'beweg': 539,
#  'koch': 540,
#  'schwimme': 541,
#  'hasslich': 542,
#  'brav': 543,
#  'muhe': 544,
#  'fliegen': 545,
#  'zuerst': 546,
#  'jahre': 547,
#  'verzieh': 548,
#  'verschwinde': 549,
#  'repariert': 550,
#  'hilf': 551,
#  'uberlebt': 552,
#  'echt': 553,
#  'durch': 554,
#  'wurdest': 555,
#  'morgen': 556,
#  'job': 557,
#  'ruhe': 558,
#  'nass': 559,
#  'meinung': 560,
#  'fische': 561,
#  'schuldig': 562,
#  'fahrrad': 563,
#  'gegeben': 564,
#  'anrufen': 565,
#  'manner': 566,
#  'egal': 567,
#  'notizen': 568,
#  'schneide': 569,
#  'zwei': 570,
#  'schalte': 571,
#  'ziehen': 572,
#  'hoch': 573,
#  'yoga': 574,
#  'verstecken': 575,
#  'gewahlt': 576,
#  'milch': 577,
#  'ding': 578,
#  'sang': 579,
#  'bekam': 580,
#  'blieb': 581,
#  'taub': 582,
#  'gefeuert': 583,
#  'wiedersehen': 584,
#  'passiert': 585,
#  'legt': 586,
#  'unten': 587,
#  'nochmal': 588,
#  'scharf': 589,
#  'tat': 590,
#  'gewinne': 591,
#  'kennst': 592,
#  'gewesen': 593,
#  'augenblick': 594,
#  'aufgestanden': 595,
#  'spion': 596,
#  'erbrochen': 597,
#  'hingehen': 598,
#  'gehorchen': 599,
#  'ubel': 600,
#  'ordentlich': 601,
#  'grausam': 602,
#  'reparieren': 603,
#  'sicherheit': 604,
#  'oft': 605,
#  'pingelig': 606,
#  'beeilt': 607,
#  'weint': 608,
#  'rennt': 609,
#  'steh': 610,
#  'lernen': 611,
#  'damlich': 612,
#  'vorne': 613,
#  'hielt': 614,
#  'sprach': 615,
#  'verstanden': 616,
#  'liste': 617,
#  'faul': 618,
#  'freundlich': 619,
#  'toll': 620,
#  'zah': 621,
#  'versuch': 622,
#  'studiere': 623,
#  'spiele': 624,
#  'dein': 625,
#  'gerettet': 626,
#  'vermissen': 627,
#  'soweit': 628,
#  'fiel': 629,
#  'fleisch': 630,
#  'ok': 631,
#  'fliege': 632,
#  'punktlich': 633,
#  'heute': 634,
#  'sorgen': 635,
#  'rief': 636,
#  'folgen': 637,
#  'pferd': 638,
#  'waffe': 639,
#  'schaut': 640,
#  'genau': 641,
#  'koche': 642,
#  'offne': 643,
#  'traumen': 644,
#  'musik': 645,
#  'tritt': 646,
#  'schlau': 647,
#  'sauer': 648,
#  'rufen': 649,
#  'rufe': 650,
#  'vorsicht': 651,
#  'klappt': 652,
#  'spring': 653,
#  'rate': 654,
#  'stoppen': 655,
#  'mogen': 656,
#  'lustig': 657,
#  'gar': 658,
#  'haltet': 659,
#  'schlief': 660,
#  'glaube': 661,
#  'nacht': 662,
#  'hau': 663,
#  'setzen': 664,
#  'nachste': 665,
#  'man': 666,
#  'schaffen': 667,
#  'dagegen': 668,
#  'helfe': 669,
#  'tue': 670,
#  'entschuldigung': 671,
#  'heraus': 672,
#  'geantwortet': 673,
#  'benotige': 674,
#  'wollte': 675,
#  'gerecht': 676,
#  'drinnen': 677,
#  'rechnung': 678,
#  'holen': 679,
#  'kannte': 680,
#  'schwindlig': 681,
#  'tapfer': 682,
#  'abendessen': 683,
#  'gelacht': 684,
#  'krieg': 685,
#  'apfel': 686,
#  'behalt': 687,
#  'seite': 688,
#  'kaufe': 689,
#  'hut': 690,
#  'gewitzt': 691,
#  'gewarnt': 692,
#  'alleine': 693,
#  'geschummelt': 694,
#  'schrecklich': 695,
#  'gefragt': 696,
#  'fahr': 697,
#  'jemand': 698,
#  'wehgetan': 699,
#  'trank': 700,
#  'davon': 701,
#  'gebaut': 702,
#  'beliebt': 703,
#  'nutzlos': 704,
#  'umziehen': 705,
#  'schlittschuh': 706,
#  'gesund': 707,
#  'verlaufen': 708,
#  'brauchst': 709,
#  'sause': 710,
#  'wussten': 711,
#  'beruhige': 712,
#  'machte': 713,
#  'geworden': 714,
#  'furchte': 715,
#  'schwierig': 716,
#  'verlasse': 717,
#  'traume': 718,
#  'eines': 719,
#  'brach': 720,
#  'verlassen': 721,
#  'verlor': 722,
#  'hoflich': 723,
#  'schreibe': 724,
#  'repariere': 725,
#  'augen': 726,
#  'leiden': 727,
#  'gefahren': 728,
#  'bis': 729,
#  'guck': 730,
#  'druck': 731,
#  'pack': 732,
#  'letzte': 733,
#  'verschwunden': 734,
#  'half': 735,
#  'geduldig': 736,
#  'ne': 737,
#  'troll': 738,
#  'vertrauen': 739,
#  'isst': 740,
#  'dunkel': 741,
#  'groer': 742,
#  'eingestellt': 743,
#  'angekommen': 744,
#  'moment': 745,
#  'schwirr': 746,
#  'richtung': 747,
#  'nackt': 748,
#  'guter': 749,
#  'zisch': 750,
#  'lieber': 751,
#  'gelassen': 752,
#  'neugierig': 753,
#  'grund': 754,
#  'aufstehen': 755,
#  'lauf': 756,
#  'mama': 757,
#  'drum': 758,
#  'trotzdem': 759,
#  'vergiss': 760,
#  'herunter': 761,
#  'leicht': 762,
#  'tote': 763,
#  'nervos': 764,
#  'spreche': 765,
#  'kuchen': 766,
#  'gesprochen': 767,
#  'verdufte': 768,
#  'rede': 769,
#  'behaltet': 770,
#  'kicherte': 771,
#  'heim': 772,
#  'durst': 773,
#  'machs': 774,
#  'hungrig': 775,
#  'unglucklich': 776,
#  'verliebt': 777,
#  'kocht': 778,
#  'sicherheitsdienst': 779,
#  'montag': 780,
#  'verkrumele': 781,
#  'deins': 782,
#  'hore': 783,
#  'uberprufen': 784,
#  'spater': 785,
#  'geschlafen': 786,
#  'schlaft': 787,
#  'wasch': 788,
#  'gas': 789,
#  'acker': 790,
#  'spricht': 791,
#  'geschehen': 792,
#  'denken': 793,
#  'herbst': 794,
#  'gnadenlos': 795,
#  'wichtig': 796,
#  'reicht': 797,
#  'darum': 798,
#  'zimmer': 799,
#  'mary': 800,
#  'typ': 801,
#  'wart': 802,
#  'kreativ': 803,
#  'unseres': 804,
#  'weine': 805,
#  'umarmen': 806,
#  'dj': 807,
#  'satt': 808,
#  'schreibt': 809,
#  'versuche': 810,
#  'gesicht': 811,
#  'lungen': 812,
#  'stimmte': 813,
#  'fassen': 814,
#  'bezahle': 815,
#  'funktionieren': 816,
#  'schaute': 817,
#  'gearbeitet': 818,
#  'leichtglaubig': 819,
#  'nachdenken': 820,
#  'hey': 821,
#  'naher': 822,
#  'verbindung': 823,
#  'bleibe': 824,
#  'gleich': 825,
#  'nummer': 826,
#  'zahle': 827,
#  'glauben': 828,
#  'lugst': 829,
#  'verwirrt': 830,
#  'idiot': 831,
#  'rieche': 832,
#  'menschen': 833,
#  'wort': 834,
#  'trat': 835,
#  'versagen': 836,
#  'schmutzig': 837,
#  'langweile': 838,
#  'unwohl': 839,
#  'unsere': 840,
#  'schrie': 841,
#  'bins': 842,
#  'verschlafen': 843,
#  'nickerchen': 844,
#  'grundlich': 845,
#  'toten': 846,
#  'nochmals': 847,
#  'glatze': 848,
#  'scherzen': 849,
#  'umarmt': 850,
#  'uberleben': 851,
#  'andern': 852,
#  'ihre': 853,
#  'minute': 854,
#  'falsch': 855,
#  'werdet': 856,
#  'klatschen': 857,
#  'perfekt': 858,
#  'kontrollieren': 859,
#  'wurden': 860,
#  'wachsam': 861,
#  'gebt': 862,
#  'denn': 863,
#  'mutter': 864,
#  'entscheiden': 865,
#  'brot': 866,
#  'schreib': 867,
#  'deckung': 868,
#  'stimmen': 869,
#  'umarmte': 870,
#  'loch': 871,
#  'gehabt': 872,
#  'sterbe': 873,
#  'zwilling': 874,
#  'lebt': 875,
#  'faust': 876,
#  'aufgehort': 877,
#  'zusammen': 878,
#  'amusiert': 879,
#  'hasste': 880,
#  'freude': 881,
#  'schick': 882,
#  'hasst': 883,
#  'zeigs': 884,
#  'traf': 885,
#  'bremste': 886,
#  'lang': 887,
#  'meinem': 888,
#  'sitzen': 889,
#  'wen': 890,
#  'finden': 891,
#  'verdient': 892,
#  'geirrt': 893,
#  'zahn': 894,
#  'siegen': 895,
#  'lerne': 896,
#  'eis': 897,
#  'gewachsen': 898,
#  'zahlen': 899,
#  'entkommen': 900,
#  'zuruckgekommen': 901,
#  'single': 902,
#  'stehe': 903,
#  'folge': 904,
#  'geschwommen': 905,
#  'joggen': 906,
#  'froh': 907,
#  'niemandem': 908,
#  'lachen': 909,
#  'bewaffnet': 910,
#  'stadt': 911,
#  'scherz': 912,
#  'regnet': 913,
#  'stellen': 914,
#  'traum': 915,
#  'feuer': 916,
#  'landkarte': 917,
#  'kummern': 918,
#  'schoss': 919,
#  'entspann': 920,
#  'singt': 921,
#  'frage': 922,
#  'lernt': 923,
#  'jungen': 924,
#  'sagten': 925,
#  'wahnsinnig': 926,
#  'setzte': 927,
#  'plan': 928,
#  'kunstler': 929,
#  'bescheiden': 930,
#  'wenig': 931,
#  'machst': 932,
#  'antworten': 933,
#  'bete': 934,
#  'fue': 935,
#  'bringt': 936,
#  'zieht': 937,
#  'blinzelte': 938,
#  'sagt': 939,
#  'betete': 940,
#  'richtig': 941,
#  'fantastisch': 942,
#  'bekifft': 943,
#  'student': 944,
#  'mager': 945,
#  'aufrichtig': 946,
#  'ei': 947,
#  'ungerecht': 948,
#  'hinein': 949,
#  'mathematik': 950,
#  'gefangen': 951,
#  'blass': 952,
#  'ahnung': 953,
#  'schwindelig': 954,
#  'stimme': 955,
#  'fuhre': 956,
#  'bewegte': 957,
#  'irre': 958,
#  'schnee': 959,
#  'diskret': 960,
#  'doste': 961,
#  'geschieden': 962,
#  'wars': 963,
#  'magst': 964,
#  'offnen': 965,
#  'tresor': 966,
#  'normal': 967,
#  'rechts': 968,
#  'tor': 969,
#  'tag': 970,
#  'betrogen': 971,
#  'finde': 972,
#  'halfen': 973,
#  'falschung': 974,
#  'besorgt': 975,
#  'brechen': 976,
#  'stirbt': 977,
#  'selten': 978,
#  'geruhrt': 979,
#  'irrst': 980,
#  'vergeht': 981,
#  'mitmachen': 982,
#  'ungewohnlich': 983,
#  'pizza': 984,
#  'langer': 985,
#  'ubernimm': 986,
#  'munze': 987,
#  'ufo': 988,
#  'lied': 989,
#  'lachte': 990,
#  'gucken': 991,
#  'winter': 992,
#  'regnen': 993,
#  'soll': 994,
#  'ruhr': 995,
#  'schlimm': 996,
#  'boden': 997,
#  'einfaltig': 998,
#  'verehre': 999,
#  'gewehr': 1000,
#  ...}

# %%
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
    # integer encode sequences
    X = tokenizer.texts_to_sequences(lines)
    # pad sequences with 0 values
    X = pad_sequences(X, maxlen=length, padding='post')
    return X

# %%
# one hot encode target sequence
def encode_output(sequences, vocab_size):
    ylist = list()
    for sequence in sequences:
        encoded = to_categorical(sequence, num_classes=vocab_size)
        ylist.append(encoded)
    y = array(ylist)
    y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
    return y

# %%
# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
    model = Sequential()
    model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
    model.add(LSTM(n_units))
    model.add(RepeatVector(tar_timesteps))
    model.add(LSTM(n_units, return_sequences=True))
    model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy')
    # summarize defined model
    model.summary()
#     plot_model(model, to_file='model.png', show_shapes=True)
    return model

# %%
# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))

# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('German Vocabulary Size: %d' % ger_vocab_size)
print('German Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)

# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
# fit model
#checkpoint = ModelCheckpoint('model.h5', monitor='val_loss', verbose=1,save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=30, batch_size=64, validation_data=(testX, testY)
          , verbose=2)
model.save('model.h5')  # Save as an HDF5 file
# Out:
# English Vocabulary Size: 2172
# English Max Length: 5
# German Vocabulary Size: 3578
# German Max Length: 8
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_10 (LSTM)                       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ repeat_vector_5 (RepeatVector)       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_11 (LSTM)                       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_5 (TimeDistributed) │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 141/141 - 21s - 150ms/step - loss: 4.0528 - val_loss: 3.3117
# Epoch 2/30
# 141/141 - 12s - 89ms/step - loss: 3.1780 - val_loss: 3.1548
# Epoch 3/30
# 141/141 - 12s - 88ms/step - loss: 3.0032 - val_loss: 3.0114
# Epoch 4/30
# 141/141 - 12s - 88ms/step - loss: 2.8351 - val_loss: 2.9130
# Epoch 5/30
# 141/141 - 13s - 92ms/step - loss: 2.7012 - val_loss: 2.8121
# Epoch 6/30
# 141/141 - 13s - 96ms/step - loss: 2.5586 - val_loss: 2.6999
# Epoch 7/30
# 141/141 - 13s - 91ms/step - loss: 2.4130 - val_loss: 2.6056
# Epoch 8/30
# 141/141 - 13s - 91ms/step - loss: 2.2769 - val_loss: 2.4946
# Epoch 9/30
# 141/141 - 12s - 89ms/step - loss: 2.1401 - val_loss: 2.3930
# Epoch 10/30
# 141/141 - 13s - 90ms/step - loss: 2.0033 - val_loss: 2.3306
# Epoch 11/30
# 141/141 - 14s - 102ms/step - loss: 1.8789 - val_loss: 2.2526
# Epoch 12/30
# 141/141 - 13s - 92ms/step - loss: 1.7562 - val_loss: 2.1852
# Epoch 13/30
# 141/141 - 13s - 91ms/step - loss: 1.6442 - val_loss: 2.1280
# Epoch 14/30
# 141/141 - 13s - 92ms/step - loss: 1.5407 - val_loss: 2.0857
# Epoch 15/30
# 141/141 - 13s - 93ms/step - loss: 1.4447 - val_loss: 2.0329
# Epoch 16/30
# 141/141 - 13s - 92ms/step - loss: 1.3493 - val_loss: 1.9954
# Epoch 17/30
# 141/141 - 13s - 93ms/step - loss: 1.2587 - val_loss: 1.9662
# Epoch 18/30
# 141/141 - 13s - 92ms/step - loss: 1.1725 - val_loss: 1.9330
# Epoch 19/30
# 141/141 - 13s - 91ms/step - loss: 1.0865 - val_loss: 1.9098
# Epoch 20/30
# 141/141 - 13s - 91ms/step - loss: 1.0098 - val_loss: 1.8813
# Epoch 21/30
# 141/141 - 13s - 92ms/step - loss: 0.9310 - val_loss: 1.8598
# Epoch 22/30
# 141/141 - 20s - 144ms/step - loss: 0.8567 - val_loss: 1.8309
# Epoch 23/30
# 141/141 - 13s - 93ms/step - loss: 0.7888 - val_loss: 1.8342
# Epoch 24/30
# 141/141 - 21s - 146ms/step - loss: 0.7227 - val_loss: 1.8064
# Epoch 25/30
# 141/141 - 13s - 91ms/step - loss: 0.6606 - val_loss: 1.7933
# Epoch 26/30
# 141/141 - 13s - 90ms/step - loss: 0.6053 - val_loss: 1.7856
# Epoch 27/30
# 141/141 - 13s - 91ms/step - loss: 0.5527 - val_loss: 1.7896
# Epoch 28/30
# 141/141 - 13s - 91ms/step - loss: 0.5102 - val_loss: 1.7731
# Epoch 29/30
# 141/141 - 13s - 92ms/step - loss: 0.4684 - val_loss: 1.7673
# Epoch 30/30
# 141/141 - 13s - 92ms/step - loss: 0.4265 - val_loss: 1.7676
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Evaluate Neural Translation Model

# %%
from numpy import argmax

from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# %%
# map an integer to a word
def word_for_id(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# %%
# generate target given source sequence
def predict_sequence(model, tokenizer, source):
    prediction = model.predict(source, verbose=0)[0]
    integers = [argmax(vector) for vector in prediction]
    target = list()
    for i in integers:
        word = word_for_id(i, tokenizer)
        if word is None:
            break
        target.append(word)
    return ' '.join(target)

# %%
# evaluate the skill of the model
def evaluate_model(model, sources, raw_dataset):
    actual, predicted = list(), list()
    for i, source in enumerate(sources):
        # translate encoded source text
        source = source.reshape((1, source.shape[0]))
        translation = predict_sequence(model, eng_tokenizer, source)
        raw_target, raw_src, desc= raw_dataset[i]
        if i < 10:
            print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
        actual.append(raw_target.split())
        predicted.append(translation.split())
    # calculate BLEU score
    print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
    print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
    print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
    print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# %%
# evaluate_model(model, trainX, train)
# source = source.reshape((1, source.shape[0]))
# trainX.reshape((1, trainX.shape[0]))
print('Shape of the data is',trainX.shape[0])
print(trainX)
print('\n')

for i, source in enumerate(trainX):
    print(f'Index{i} :souurce{source}')
# Out:
# Shape of the data is 9000
# [[   2   25  235 ...    0    0    0]
#  [   1   40 1300 ...    0    0    0]
#  [   8   63    2 ...    0    0    0]
#  ...
#  [  11  141    0 ...    0    0    0]
#  [   1    7 3405 ...    0    0    0]
#  [   1  199   18 ...    0    0    0]]
#
#
# Index0 :souurce[  2  25 235   0   0   0   0   0]
# Index1 :souurce[   1   40 1300    0    0    0    0    0]
# Index2 :souurce[  8  63   2 201   0   0   0   0]
# Index3 :souurce[   1 1891    6    0    0    0    0    0]
# Index4 :souurce[  1  43 959   0   0   0   0   0]
# Index5 :souurce[480  71   0   0   0   0   0   0]
# Index6 :souurce[ 99   1  14 664   0   0   0   0]
# Index7 :souurce[   1  481 1892    0    0    0    0    0]
# Index8 :souurce[  4  13  41 386   0   0   0   0]
# Index9 :souurce[19  4 34  0  0  0  0  0]
# Index10 :souurce[  2   3  16 236   0   0   0   0]
# Index11 :souurce[  1  17 482 560   0   0   0   0]
# Index12 :souurce[  90   49   35 1301    0    0    0    0]
# Index13 :souurce[ 12  32  64 665   0   0   0   0]
# Index14 :souurce[278  75  11   9   0   0   0   0]
# Index15 :souurce[ 65 960   0   0   0   0   0   0]
# Index16 :souurce[51 52  0  0  0  0  0  0]
# Index17 :souurce[215 279   0   0   0   0   0   0]
# Index18 :souurce[25  1 86  0  0  0  0  0]
# Index19 :souurce[   1   10 1893 1302    0    0    0    0]
# Index20 :souurce[ 46   5 109   0   0   0   0   0]
# Index21 :souurce[   1   10 1894 1303    0    0    0    0]
# Index22 :souurce[  1  10  14 387   0   0   0   0]
# Index23 :souurce[ 11 791 100   0   0   0   0   0]
# Index24 :souurce[1304    0    0    0    0    0    0    0]
# Index25 :souurce[  4  63 105   0   0   0   0   0]
# Index26 :souurce[  6   3 173   0   0   0   0   0]
# Index27 :souurce[ 38   3 792   0   0   0   0   0]
# Index28 :souurce[  2 961   0   0   0   0   0   0]
# Index29 :souurce[ 50  41 150   0   0   0   0   0]
# Index30 :souurce[  11 1895    5    0    0    0    0    0]
# Index31 :souurce[  8  19 280   0   0   0   0   0]
# Index32 :souurce[   6   25  666   42   64 1305  483    0]
# Index33 :souurce[  1 561 174   0   0   0   0   0]
# Index34 :souurce[  8 793 168   0   0   0   0   0]
# Index35 :souurce[202   4   5 169   0   0   0   0]
# Index36 :souurce[  27 1306   72    0    0    0    0    0]
# Index37 :souurce[  8 313 295   0   0   0   0   0]
# Index38 :souurce[   6    3 1307    0    0    0    0    0]
# Index39 :souurce[  1 561 175   0   0   0   0   0]
# Index40 :souurce[  2   3 484   0   0   0   0   0]
# Index41 :souurce[ 30  65 250   0   0   0   0   0]
# Index42 :souurce[  1  10 227  92  21   0   0   0]
# Index43 :souurce[  1   7 962   0   0   0   0   0]
# Index44 :souurce[  1 314   2   0   0   0   0   0]
# Index45 :souurce[ 1 62  2  0  0  0  0  0]
# Index46 :souurce[  4  19 315   0   0   0   0   0]
# Index47 :souurce[  5   3  61 281   0   0   0   0]
# Index48 :souurce[ 64 794   3 237   0   0   0   0]
# Index49 :souurce[  5 251  49   9 252  15  83   0]
# Index50 :souurce[ 23 963   0   0   0   0   0   0]
# Index51 :souurce[  2  13 388   0   0   0   0   0]
# Index8987 :souurce[   2 3404   29    0    0    0    0    0]
# Index8988 :souurce[  6   3 153   0   0   0   0   0]
# Index8989 :souurce[  2  13 126   0   0   0   0   0]
# Index8990 :souurce[  2   3 808   0   0   0   0   0]
# Index8991 :souurce[  4 105   0   0   0   0   0   0]
# Index8992 :souurce[  5  17 139   0   0   0   0   0]
# Index8993 :souurce[1226  371    0    0    0    0    0    0]
# Index8994 :souurce[730 291   0   0   0   0   0   0]
# Index8995 :souurce[1246  662    0    0    0    0    0    0]
# Index8996 :souurce[50 22 44 33  0  0  0  0]
# Index8997 :souurce[ 11 141   0   0   0   0   0   0]
# Index8998 :souurce[   1    7 3405    0    0    0    0    0]
# Index8999 :souurce[  1 199  18 192 635   0   0   0]

# %%
# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# %%
# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, testX, test)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# train
# src=[tom kann laufen], target=[tom can walk], predicted=[tom can win]
# src=[ich mag kunst], target=[i like art], predicted=[i like art]
# src=[wir werden tom fragen], target=[well ask tom], predicted=[well ask tom]
# src=[ich verwende das], target=[i use this], predicted=[i use this]
# src=[ich liebe schnee], target=[i love snow], predicted=[i love snow]
# src=[lies weiter], target=[keep reading], predicted=[keep reading]
# src=[darf ich mich setzen], target=[can i sit down], predicted=[may i sit]
# src=[ich gebe franzosischunterricht], target=[i teach french], predicted=[i cried french]
# src=[sie hat ihn geschlagen], target=[she hit him], predicted=[she hit him]
# src=[sind sie hier], target=[are you here], predicted=[are they here]
# BLEU-1: 0.088656
# BLEU-2: 0.000000
# BLEU-3: 0.000000
# BLEU-4: 0.000000
# test
# src=[tom wird gehasst], target=[tom is hated], predicted=[tom will pay]
# src=[auf wiedersehen], target=[see you again], predicted=[goodbye]
# src=[alle lugen], target=[everybody lies], predicted=[whos vanished]
# src=[beschwer dich nicht], target=[dont complain], predicted=[dont move]
# src=[tom kam zu spat], target=[tom was late], predicted=[tom is home]
# src=[er wird nicht gehen], target=[he will not go], predicted=[he wont go]
# src=[ist das klug], target=[is that wise], predicted=[is this weird]
# src=[sie sind hoflich], target=[youre polite], predicted=[youre polite]
# src=[ich bin mit dem bus gekommen], target=[i came by bus], predicted=[im on by car]
# src=[ich bin schrecklich], target=[im horrible], predicted=[im ready]
# BLEU-1: 0.102973
# BLEU-2: 0.000000
# BLEU-3: 0.000000
# BLEU-4: 0.000000
